# %% [markdown]
# 1. Draw the together lines $L_1, L_2$ produced, respectively, by 1) the slope vector $\vec{m}_1 = \hat{e}_x + \hat{e}_y$ and shift $\vec{b}_1 = \hat{e}_y$ and 2) the slope vector $\vec{m}_2 -\hat{e}_x + \hat{e}_y$ and shift $\vec{b}_2 = -\hat{e}_y$. Then, label the vector $\vec{r}_{12}$ that points to their intersection.

# %%
#

# %% [markdown]
# 2. Two vectors $\vec{A}$ and $\vec{B}$ are in a plane together. Vector $\vec{A}$ has a length of 15 and a forms a $40\degree$ angle above the _positive_ direction of the $x$-axis. Vector $\vec{B}$ has a length of 8 and forms a $30\degree$ above the _negative_ direction of the $x$-axis.
#
#     a. Plot them together with their sum $\vec{A}+\vec{B}$ and label their angles with the $x$-axis.
#
#     b. Draw $\vec{A}$ & $\vec{B}$ together with the parallel-translated forms of $\vec{A}$ and $\vec{B}$ and their sum $\vec{A}+\vec{B}$ to illustrate the parallelogram rule.

# %%
#

# %% [markdown]
# 3. Two vectors $\vec{C}$ and $\vec{D}$ are in a plane together. $\vec{C}$ has length 20 and forms a $60\degree$ angle above the positive direction of the  $x$-axis. $\vec{D}$ has a length of 12 and forms a $45\degree$ angle below the negative direction of the $x$-axis.
#
#     a. Find a third vector $\vec{E}$ so that $\vec{C}+\vec{D}+\vec{E}=\vec{0}$.
#
#     b. Plot them using the head-to-tail method to show that they return to the origin.

# %%
#

# %% [markdown]
# 4. Write a code that draws $N$ two-dimensional vectors head-to-tail in the form of a regular polygon centered around the origin starting with shift $\vec{r}_0=\hat{e}_y$. The initial vector should make an angle of $90\degree - \frac{180\degree}{N}$ down and to the left from the head of $\vec{r}_0$ and have length of $\ell_N = \sqrt{2\left(1 + \cos \frac{360\degree}{N}\right)}$. Do $N=3, 4, 5, 10, 100$. On each plot, calculate and print the sum of the lengths of the vectors. Bonus: derive the expression for these.

# %%
#
