# %% [markdown]
# # Vector Addition

# %% [markdown]
# $\vec{a} + \vec{b}$

# %% [markdown]
# ## Component-wise Addition
# $\vec{a}+\vec{b} = (a_x + b_x)\hat{e}_x + (a_y + b_y)\hat{e}_y$

# %%
import numpy as np
from vectors import add


vector_a = np.array([1, 2, 3])
vector_b = np.array([4, 5, 6])

print(np.array(add(vector_a, vector_b)))
# Out:
# [5 7]

# %% [markdown]
# # Vector Subtraction

# %% [markdown]
# # Scalar Multiplication

# %% [markdown]
# # Scalar Product

# %% [markdown]
# # Vector Product
